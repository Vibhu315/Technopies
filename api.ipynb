# %%
from flask import Flask, render_template, request
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np
import cv2

app = Flask(_name_)

# Load the pre-trained machine learning model
model = load_model('/content/drive/MyDrive/model.h5')
class_names = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']

# Define the home page route
@app.route('/')
def home():
    return render_template('diseasesdetect.html')

# Define the prediction route
@app.route('/predict', methods=['POST'])
def predict():
    # Get the uploaded image file from the form
    image_file = request.files['image']

    # Read the image file and convert to a numpy array
    img = cv2.imdecode(np.frombuffer(image_file.read(), np.uint8), cv2.IMREAD_COLOR)
    img = cv2.resize(img, (224, 224)) # Resize the image to match the input size of the model
    img = np.expand_dims(img, axis=0) # Add an extra dimension for batch size

    # Normalize the input image
    img = img / 255.0

    # Call the model to obtain the output prediction
    predictions = model.predict(img)

    # Convert the prediction probabilities to class names
    predicted_class = class_names[np.argmax(predictions)]

    # Return the prediction to the web page
    return render_template('index.html', prediction_text='The predicted class is {}'.format(predicted_class))

if _name_ == '_main_':
    app.run(debug=True)

# %%
from flask import Flask, render_template, request
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np
import cv2

app = Flask(__name__)
upload_html = "main/diseasedetect.html"
# Load the pre-trained machine learning model
class_names = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']

# Define the home page route
@app.route('/')
def home():
    return render_template(upload_html)

# Define the prediction route
@app.route('/predict', methods=['POST'])
def predict():
    # Get the uploaded image file from the form
    image_file = request.files['image']

    # Read the image file and convert to a numpy array
    img = cv2.imdecode(np.frombuffer(image_file.read(), np.uint8), cv2.IMREAD_COLOR)
    img = cv2.resize(img, (224, 224)) # Resize the image to match the input size of the model
    img = np.expand_dims(img, axis=0) # Add an extra dimension for batch size

    # Normalize the input image
    img = img / 255.0

    # Call the model to obtain the output prediction
    predictions = model.predict(img)

    # Convert the prediction probabilities to class names
    ind = np.argmax(predictions)
    predicted_class = class_names[ind]

    # Return the prediction to the web page
    return render_template(upload_html, prediction_text='The predicted class is {}'.format(predicted_class))

if __name__ == '__main__':
    app.run(debug=True)

import requests


output = "class_names[np.argmax(predictions)]"
 # Replace this with your actual output
url = "https://www.amazon.in/s?k=fungicidial+dprayer&crid=1Y5VNJZGTM2IK&sprefix=fungicidial+dprayer%2Caps%2C174&ref=nb_sb_noss" # Replace this with your actual URL

response = requests.post(url,data=predicted_class)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-94ee029e8fe1> in <cell line: 51>()
#      49 url = "https://www.amazon.in/s?k=fungicidial+dprayer&crid=1Y5VNJZGTM2IK&sprefix=fungicidial+dprayer%2Caps%2C174&ref=nb_sb_noss" # Replace this with your actual URL
#      50
# ---> 51 response = requests.post(url,data=predicted_class)
#
# NameError: name 'predicted_class' is not defined
